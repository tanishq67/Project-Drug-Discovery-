# %% [markdown]
# # **QSAR Model Building of Aromatase Inhibitors**

# %% [markdown]
# # Read in data

# %%
import pandas as pd

# %%
dataset_url = 'https://raw.githubusercontent.com/tanishq67/Project-Drug-Discovery-/4c94be85722ac0d616bb28aba20997593e049642/Data/Aromatase_bioactivity_data_3class_pIC50_pubchem_fp.csv'
dataset = pd.read_csv(dataset_url)
dataset
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  4.301030
# 1              1           1           1  ...             0             0  6.623423
# 2              1           1           1  ...             0             0  7.244125
# 3              1           1           1  ...             0             0  7.267606
# 4              1           1           1  ...             0             0  7.387216
# ...          ...         ...         ...  ...           ...           ...       ...
# 1968           1           1           0  ...             0             0  5.475574
# 1969           1           1           1  ...             0             0  5.000000
# 1970           1           1           0  ...             0             0  5.000000
# 1971           1           1           1  ...             0             0       NaN
# ...

# %%
dataset.dropna(subset=['pIC50'], inplace=True)

# %%
X = dataset.drop(['pIC50'], axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 1967           1           1  ...             0             0
# 1968           1           1  ...             0             0
# 1969           1           1  ...             0             0
# 1970           1           1  ...             0             0
# 1972           1           1  ...             0             0
#
# [1926 rows x 881 columns]

# %%
Y = dataset.iloc[:,-1]
Y
# Out:
# 0       4.301030
# 1       6.623423
# 2       7.244125
# 3       7.267606
# 4       7.387216
#           ...
# 1967    5.458153
# 1968    5.475574
# 1969    5.000000
# 1970    5.000000
# 1972    6.455932
# Name: pIC50, Length: 1926, dtype: float64

# %% [markdown]
# # Remove low variance features

# %%
from sklearn.feature_selection import VarianceThreshold

def remove_low_variance(input_data, threshold=0.1):
    selection = VarianceThreshold(threshold)
    selection.fit(input_data)
    return input_data[input_data.columns[selection.get_support(indices=True)]]

X = remove_low_variance(X, threshold=0.1)
X
# Out:
#       PubchemFP2  PubchemFP12  ...  PubchemFP819  PubchemFP860
# 0              1            1  ...             0             0
# 1              1            1  ...             0             1
# 2              1            1  ...             0             0
# 3              1            1  ...             0             0
# 4              1            1  ...             0             0
# ...          ...          ...  ...           ...           ...
# 1967           1            1  ...             0             0
# 1968           0            1  ...             0             0
# 1969           1            1  ...             0             0
# 1970           0            1  ...             0             0
# 1972           1            1  ...             0             0
#
# [1926 rows x 238 columns]

# %%
X.to_csv('descriptor_list.csv', index = False)

# %% [markdown]
# #Decision Tree Regression Model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = DecisionTreeRegressor()
model.fit(X, Y)
r2 = model.score(X, Y)
r2
# Out:
# 0.6128712718290878

# %% [markdown]
# ## Model Prediction

# %%
Y_pred = model.predict(X)
Y_pred
# Out:
# array([7.2751961 , 6.62342304, 7.2751961 , ..., 5.        , 6.32561752,
#        6.39423304])

# %% [markdown]
# ## Model Performance

# %%
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y, Y_pred))
# Out:
# Mean squared error (MSE): 0.78
# Coefficient of determination (R^2): 0.61

# %% [markdown]
# # Data Visualization (Experimental vs Predicted pIC50 for Training Data)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=Y, y=Y_pred, c="#7CAE00", alpha=0.3)

# Add trendline
# https://stackoverflow.com/questions/26447191/how-to-add-trendline-in-python-matplotlib-dot-scatter-graphs
z = np.polyfit(Y, Y_pred, 1)
p = np.poly1d(z)

plt.plot(Y,p(Y),"#F8766D")
plt.ylabel('Predicted pIC50')
plt.xlabel('Experimental pIC50')
# Out:
# Text(0.5, 0, 'Experimental pIC50')

# %% [markdown]
# # Save Model as Pickle Object

# %%
import pickle

# %%
pickle.dump(model, open('Aromatase_model.pkl', 'wb'))
